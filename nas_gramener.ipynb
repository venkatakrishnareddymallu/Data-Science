# %% [markdown]
# <h2>EXPLORATORY DATA ANALYSIS ON NATIONAL ACHIEVEMENTS <br>SURVEY USING DESCRIPTIVE STATISTICS<h2>

# %%
#importing libraries for Data Frames using Pandas and Numerical analysis using Python
import numpy as np
import pandas as pd

# %%
#importing libraries fro Data Visualization 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Reading CSV file from the System
df=pd.read_csv('nas-pupil-marks.csv')

# %%
#Display the top five data points in file 
df.head()
# Out:
#          STUID State  District  Gender  Age  Category  Same language  \
# 0  11011001001    AP         1       1    3         3              1
# 1  11011001002    AP         1       2    3         4              2
# 2  11011001003    AP         1       2    3         4              2
# 3  11011001004    AP         1       2    3         3              2
# 4  11011001005    AP         1       2    3         3              2
#
#    Siblings  Handicap  Father edu    ...     Express science views  Watch TV  \
# 0         5         2           1    ...                         3         3
# 1         5         2           2    ...                         3         4
# 2         5         2           1    ...                         3         4
# 3         4         2           1    ...                         3         4
# 4         5         2           1    ...                         3         2
#
#    Read magazine  Read a book  Play games Help in household  Maths %  \
# ...

# %%
#shape of the Data set
df.shape
# Out:
# (185348, 64)

# %%
#information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185348 entries, 0 to 185347
# Data columns (total 64 columns):
# STUID                     185348 non-null int64
# State                     185348 non-null object
# District                  185348 non-null int64
# Gender                    185348 non-null int64
# Age                       185348 non-null int64
# Category                  185348 non-null int64
# Same language             185348 non-null int64
# Siblings                  185348 non-null int64
# Handicap                  185348 non-null int64
# Father edu                185348 non-null int64
# Mother edu                185348 non-null int64
# Father occupation         185348 non-null int64
# Mother occupation         185348 non-null int64
# Below poverty             185348 non-null int64
# Use calculator            185348 non-null int64
# Use computer              166186 non-null object
# Use Internet              185348 non-null int64
# ...

# %% [markdown]
# <h5>SINCE THE RECORDS OF ATTRIBUTES MATHS,SCIENCE,SOCIAL,READING HAVE ALMOST 50% MISSING VALUES FILLING THESE VALUES WITH MEAN OR AVERAGE MAY LEAD TO UNFAIR INSTEAD OF DROPPING LET'S TRANSFORM AND AGGREGATE<h5>

# %%
#Read the columns in the Dataset
df.columns
# Out:
# Index(['STUID', 'State', 'District', 'Gender', 'Age', 'Category',
#        'Same language', 'Siblings', 'Handicap', 'Father edu', 'Mother edu',
#        'Father occupation', 'Mother occupation', 'Below poverty',
#        'Use calculator', 'Use computer', 'Use Internet', 'Use dictionary',
#        'Read other books', '# Books', 'Distance', 'Computer use',
#        'Library use', 'Like school', 'Subjects', 'Give Lang HW',
#        'Give Math HW', 'Give Scie HW', 'Give SoSc HW', 'Correct Lang HW',
#        'Correct Math HW', 'Correct Scie HW', 'Correct SocS HW',
#        'Help in Study', 'Private tuition', 'English is difficult',
#        'Read English', 'Dictionary to learn', 'Answer English WB',
#        'Answer English aloud', 'Maths is difficult', 'Solve Maths',
#        'Solve Maths in groups', 'Draw geometry', 'Explain answers',
#        'SocSci is difficult', 'Historical excursions', 'Participate in SocSci',
#        'Small groups in SocSci', 'Express SocSci views',
# ...

# %% [markdown]
# <h6> CLEANING THE RECORDS AND REPLACING WITH RESPECTIVE VALUES IT
# MEANS CONVERTING NUMERICAL DATA INTO CATEGORICAL DATA <h6>

# %%
#Renaming the Abbreviated states using Dictionary
states={'AN':'Andaman & Nicobar','AP':'Andhra Pradesh','AR':'Arunachal Pradesh','BR':'Bihar','CG':'Chattisgarh','CH':'Chandigarh','DD':'Daman & Diu','DL':'Delhi','DN':'Dadra & Nagar Haveli','GA':'Goa','GJ':'Gujarat','HP':'Himachal Pradesh','HR':'Haryana','JH':'Jharkhand','JK':'Jammu & Kashmir','KA':'Karnataka','KL':'Kerala','MG':'Meghalaya','MH':'Maharashtra','MN':'Manipur','MP':'Madhya Pradesh','MZ':'Mizoram','NG':'Nagaland','OR':'Orissa','PB':'Punjab','PY':'Pondicherry','RJ':'Rajasthan','SK':'Sikkim','TN':'Tamil Nadu','TR':'Tripura','UK':'Uttarakhand','UP':'Uttar Pradesh','WB':'West Bengal'}

# %%
#mapping state names which are in abbreviated form
df['state'] = df['State'].map(states)

# %% [markdown]
# <h5>REPLACING NUMERICAL DATA WITH CATEGORICAL DATA<h5>

# %%
#Using the replace() Method to change type of Data for Better Understanding During Analysis
df['Gender'].replace([1,2],['Boy','Girl'],inplace=True)
df['Age'].replace([2,3,4,5,6,1],['12 years','13 years','14 years','15 years','16+ years','11- years'],inplace=True)
df['Father edu'].replace([5,1,0,2,3,4,],['Degree & above','Illiterate','Not applicable','Primary','Secondary','Sr secondary'],inplace=True)
df['Mother edu'].replace([5,1,0,2,3,4,],['Degree & above','Illiterate','Not applicable','Primary','Secondary','Sr secondary'],inplace=True)
df['Father occupation'].replace([4,0,3,2,8,6,5,7,1],['Clerk','Do not know','Farmer','Labourer','Professional','Business','Skilled Worker','Teacher/Lecturer','Unemployed'],inplace=True)
df['Mother occupation'].replace([4,0,3,2,8,6,5,7,1],['Clerk','Do not know','Farmer','Labourer','Professional','Business','Skilled Worker','Teacher/Lecturer','Unemployed'],inplace=True)
df['Below poverty'].replace([0,1,2],['Dont know','No','Yes'],inplace=True)
df['Use calculator'].replace([1,2],['No','Yes'],inplace=True)
df['Use dictionary'].replace([1,2],['No','Yes'],inplace=True)
df['Read other books'].replace([1,2],['No','Yes'],inplace=True)
df['Help in Study'].replace([1,2],['No','Yes'],inplace=True)
df['Give Lang HW'].replace([2,3,4,1],['1-2 times a week','3-4 times a week','Everyday','Never'],inplace=True)
df['Give Math HW'].replace([2,3,4,1],['1-2 times a week','3-4 times a week','Everyday','Never'],inplace=True)
df['Give Scie HW'].replace([2,3,4,1],['1-2 times a week','3-4 times a week','Everyday','Never'],inplace=True)
df['Give SoSc HW'].replace([2,3,4,1],['1-2 times a week','3-4 times a week','Everyday','Never'],inplace=True)
df['# Books'].replace([3,2,4,1],['11-25 books','1-10 books','25+ books','No books'],inplace=True)
df['Distance'].replace([2,3,4,1],['1-3 km','3-5 km','More than 5 km','Up to 1 km'],inplace=True)
df['Computer use'].replace([5,1,4,3,2],['Daily','No computer','Once in a week','Once in month','Never use'],inplace=True)
df['Library use'].replace([5,1,4,3,2],['More than once in a week','No library','Once in a week','Once or twice in a month','Never use'],inplace=True)
df['Private tuition'].replace([1,2],['No','Yes'],inplace=True)
df['Watch TV'].replace([4,1,2,3],['Every day','Never','Once a month','Once a week'],inplace=True)
df['Read magazine'].replace([4,1,2,3],['Every day','Never','Once a month','Once a week'],inplace=True)
df['Read a book'].replace([4,1,2,3],['Every day','Never','Once a month','Once a week'],inplace=True)
df['Play games'].replace([4,1,2,3],['Every day','Never','Once a month','Once a week'],inplace=True)
df['Help in household'].replace([4,1,2,3],['Every day','Never','Once a month','Once a week'],inplace=True)
df['Siblings'].replace([2,3,4,5],['single child','1 sibling','2siblings','3 siblings'],inplace=True)
df['Correct Lang HW'].replace([2,3,4,1],['1-2 times a week','3-4 times a week','Everyday','Never'],inplace=True)
df['Correct Math HW'].replace([2,3,4,1],['1-2 times a week','3-4 times a week','Everyday','Never'],inplace=True)
df['Correct Scie HW'].replace([2,3,4,1],['1-2 times a week','3-4 times a week','Everyday','Never'],inplace=True)
df['Correct SocS HW'].replace([2,3,4,1],['1-2 times a week','3-4 times a week','Everyday','Never'],inplace=True)
df['Maths is difficult'].replace([3,1,2],['Agree','Disagree','Neither'],inplace=True)
df['Solve Maths in groups'].replace([3,1,2],['Agree','Disagree','Neither'],inplace=True)
df['Solve Maths'].replace([3,1,2],['Agree','Disagree','Neither'],inplace=True)

# %%
df['Total']=df[['Social %','Science %','Maths %','Reading %']].mean(axis=1)

# %%
# Let's See that Data Whether the code is reflected or not
df.head(3)
# Out:
#          STUID State  District Gender       Age  Category  Same language  \
# 0  11011001001    AP         1    Boy  13 years         3              1
# 1  11011001002    AP         1   Girl  13 years         4              2
# 2  11011001003    AP         1   Girl  13 years         4              2
#
#      Siblings  Handicap  Father edu   ...   Read magazine  Read a book  \
# 0  3 siblings         2  Illiterate   ...       Every day  Once a week
# 1  3 siblings         2     Primary   ...       Every day  Once a week
# 2  3 siblings         2  Illiterate   ...     Once a week  Once a week
#
#   Play games Help in household Maths % Reading %  Science % Social %  \
# 0  Every day         Every day   20.37       NaN      27.78      NaN
# 1  Every day         Every day   12.96       NaN      38.18      NaN
# 2  Every day         Every day   27.78      70.0        NaN      NaN
#
#             state   Total
# 0  Andhra Pradesh  24.075
# 1  Andhra Pradesh  25.570
# ...

# %% [markdown]
# <h1>1.WHAT INFLUENCES STUDENTS PERFORMANCE THE MOST ?<h1>

# %% [markdown]
# <h5>1 .TO ANSWER THE QUESTION WE NEED TO AGGREGATE THE DATASET ON MARKS IN DIFFERENT SUBJECTS WITH THE FACTORS(ATTRIBUTES) AND CALCULATE  THE DIFFERENCE  OF THE MAXIMUM AND MINIMUM MARKS BASED ON PARTICULAR FACTOR THAT INFLUENCES CHILD  ON EACH SUBJECT AND VISUALIZE USING HEATMAP,FINALLY MERGE ALL THE INDIVIDUAL MARKS OF SUJBJECT BASED ON PARTICULAR FACTOR(ATTRIBUTE)  <h5>

# %% [markdown]
# <h3>CONSIDER GENDER  AS ONE OF THE  FACTOR<h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Gender'])['Maths %','Science %','Reading %','Social %','Total'].mean()
#To remove the unfair record other than gender
x.drop(0,inplace=True)
#Calculating the Difference of max and min value that influence the marks based on factor
Gender=pd.DataFrame(x.max()-x.min(),columns=['GENDER'])
# Specifying a subplot for Heatmap
fig,axs=plt.subplots(ncols=2,figsize=(16,5))
plt.figure(figsize=(25,30))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Gender,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE THE GENDER AS FACTOR HEATMAP,WE CAN SEE THAT GENDER INFLUENCE AT 1.9 MARKS IN READING WHICH IS HIGH AND 0.1 MARKS IN SCIENCE WHICH IS LOW AND 0.7 THE AGE INFLUENCE ON THE TOTAL SCORE<h6>

# %% [markdown]
# <h3>CONSIDER AGE  AS ONE OF THE  FACTOR<h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Age'])['Maths %','Science %','Reading %','Social %','Total'].mean()
x.drop(0,inplace=True)
#Calculating the Difference of max and min value that influence the marks based on factor
Age=pd.DataFrame(x.max()-x.min(),columns=['Age'])
# Specifying a subplot for Heatmap
fig,axs=plt.subplots(ncols=2,figsize=(16,6))
plt.figure(figsize=(25,30))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Age,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE THE HEATMAP AGE AS FACTOR,WE CAN SAY THAT AGE INFLUENCES 8.0 MARKS IN READING WHICH IS HIGH AND 2.9 MARKS THE LEAST
# IN SOCIAL AND THE AGE INFLUENCE ON TOTAL SCORE IS 4.1 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER SIBLINGS  AS ONE OF THE  FACTOR<h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Siblings'])['Maths %','Science %','Reading %','Social %','Total'].mean()
x.drop(1,inplace=True)
#Calculating the Difference of max and min value that influence the marks based on factor
Siblings=pd.DataFrame(x.max()-x.min(),columns=['Siblings'])
# Specifying a subplot for Heatmap
fig,axs=plt.subplots(ncols=2,figsize=(16,6))
plt.figure(figsize=(25,30))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Siblings,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE SIBLINGS AS FACTOR FROM HEATMAP,WE CAN SAY THAT AGE INFLUENCES 8.3 MARKS IN READING WHICH IS HIGH AND 1.5 MARKS THE LEAST
# IN MATHS AND THE SIBLINGS INFLUENCE ON TOTAL SCORE IS 2.4 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER FATHER EDU AS  ONE OF THE  FACTOR<h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Father edu'])['Maths %','Science %','Reading %','Social %','Total'].mean()
#Calculating the Difference of max and min value that influence the marks based on factor
Father_edu=pd.DataFrame(x.max()-x.min(),columns=['Father_edu'])
# Specifying a subplot for Heatmap
fig,axs=plt.subplots(ncols=2,figsize=(16,8))
plt.figure(figsize=(25,30))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Father_edu,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE FATHER EDUCATION AS FACTOR IN HEATMAP,WE CAN SAY THAT AGE INFLUENCES 18.8 MARKS IN READING WHICH IS HIGH AND 7.2 MARKS THE LEAST
# IN MATHS AND THE FATHER EDUCATION INFLUENCE ON TOTAL SCORE IS 11.0 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER MOTHER EDU AS ONE OF THE FACTOR<h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Mother edu'])['Maths %','Science %','Reading %','Social %','Total'].mean()
#Calculating the Difference of max and min value that influence the marks based on factor
Mother_edu=pd.DataFrame(x.max()-x.min(),columns=['Mother_edu'])
# Specifying a subplot for Heatmap
fig,axs=plt.subplots(ncols=2,figsize=(16,8))
plt.figure(figsize=(25,30))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Mother_edu,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE MOTHER EDUCATION AS FACTOR IN HEATMAP,WE CAN SAY THAT MOTHER EDUCATION INFLUENCES 18.4 MARKS IN READING WHICH IS HIGH AND 5.0 MARKS THE LEAST
# IN MATHS AND THE MOTHER EDUCATION INFLUENCE ON TOTAL SCORE IS 10.7 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER FATHER OCCUPATION AS ONE OF THE FACTOR<h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Father occupation'])['Maths %','Science %','Reading %','Social %','Total'].mean()
#Calculating the Difference of max and min value that influence the marks based on factor
Father_occupation=pd.DataFrame(x.max()-x.min(),columns=['Father_occupation'])
# Specifying a subplot for Heatmap
fig,axs=plt.subplots(ncols=2,figsize=(16,12))
plt.figure(figsize=(10,10))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Father_occupation,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE FATHER OCCUPATION AS FACTOR IN HEATMAP,WE CAN SAY THAT AGE INFLUENCES 17.4 MARKS IN READING WHICH IS HIGH AND 8.5 MARKS THE LEAST
# IN SOCIAL AND THE FATHER OCCUPATION INFLUENCE ON TOTAL SCORE IS 10.6 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER MOTHER OCCUPATION AS ONE OF THE FACTOR<h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Mother occupation'])['Maths %','Science %','Reading %','Social %','Total'].mean()
#Calculating the Difference of max and min value that influence the marks based on factor
Mother_occupation=pd.DataFrame(x.max()-x.min(),columns=['Mother_occupation'])
fig,axs=plt.subplots(ncols=2,figsize=(16,12))
plt.figure(figsize=(10,10))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Mother_occupation,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE MOTHER OCCUPATION AS FACTOR IN HEATMAP,WE CAN SAY THAT AGE INFLUENCES 14.9 MARKS IN READING WHICH IS HIGH AND 5.7 MARKS THE LEAST
# IN MATHS AND THE MOTHER OCCUPATION INFLUENCE ON TOTAL SCORE IS 9.1 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER BELOW POVERTY AS ONE OF THE FACTOR<h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Below poverty'])['Maths %','Science %','Reading %','Social %','Total'].mean()
#Calculating the Difference of max and min value that influence the marks based on factor
Below_poverty=pd.DataFrame(x.max()-x.min(),columns=['Below_poverty'])
fig,axs=plt.subplots(ncols=2,figsize=(16,5))
plt.figure(figsize=(10,10))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Below_poverty,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE  BELOW POVERTY AS FACTOR IN HEATMAP,WE CAN SAY THAT BELOW POVERTY INFLUENCES 5.7 MARKS IN READING WHICH IS HIGH AND 2.6 MARKS THE LEAST
# IN SCIENCE AND THE BELOW POVERTY INFLUENCE ON TOTAL SCORE IS 3.3 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER USE CALCULATOR AS ONE OF THE FACTOR<h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Use calculator'])['Maths %','Science %','Reading %','Social %','Total'].mean()
x.drop(0,inplace=True)
#Calculating the Difference of max and min value that influence the marks based on factor
Use_calculator=pd.DataFrame(x.max()-x.min(),columns=['Use_calculator'])
fig,axs=plt.subplots(ncols=2,figsize=(16,5))
plt.figure(figsize=(10,10))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Use_calculator,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE USE CALCULATOR AS FACTOR IN HEATMAP, WE CAN SAY THAT USE CALCULATOR INFLUENCES 5.0 MARKS IN READING WHICH IS HIGH AND 0.9 MARKS THE LEAST IN MATHS AND THE USE CALCULATOR INFLUENCE ON TOTAL SCORE IS 2.7 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER USE DICTIONARY AS ONE OF THE FACTOR<h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Use dictionary'])['Maths %','Science %','Reading %','Social %','Total'].mean()
x.drop(0,inplace=True)
#Calculating the Difference of max and min value that influence the marks based on factor
Use_dictionary=pd.DataFrame(x.max()-x.min(),columns=['Use_dictionary'])
fig,axs=plt.subplots(ncols=2,figsize=(16,5))
plt.figure(figsize=(10,10))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Use_dictionary,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE USE DICTIONARY AS FACTOR IN HEATMAP, WE CAN SAY THAT USE DICTIONARY INFLUENCES 6.4 MARKS IN READING WHICH IS HIGH AND 1.3 MARKS THE LEAST IN MATHS AND THE USE DICTIONARY INFLUENCE ON TOTAL SCORE IS 3.3 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER READ OTHER BOOKS AS ONE OF THE FACTOR<h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Read other books'])['Maths %','Science %','Reading %','Social %','Total'].mean()
x.drop(0,inplace=True)
#Calculating the Difference of max and min value that influence the marks based on factor
Read_other_books=pd.DataFrame(x.max()-x.min(),columns=['Read_other_books'])
fig,axs=plt.subplots(ncols=2,figsize=(16,5))
plt.figure(figsize=(10,10))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Read_other_books,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE READ OTHER BOOKS AS FACTOR IN HEATMAP, WE CAN SAY THAT READ OTHER INFLUENCES 6.4 MARKS IN READING WHICH IS HIGH AND 0.8 MARKS THE LEAST IN MATHS AND THE READ OTHER BOOKS INFLUENCE ON TOTAL SCORE IS 3.1 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER # BOOKS AS ONE OF THE FACTOR <h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['# Books'])['Maths %','Science %','Reading %','Social %','Total'].mean()
x.drop(0,inplace=True)
#Calculating the Difference of max and min value that influence the marks based on factor
Have_Books=pd.DataFrame(x.max()-x.min(),columns=['Have_Books'])
fig,axs=plt.subplots(ncols=2,figsize=(16,5))
plt.figure(figsize=(10,10))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Have_Books,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE #BOOKS AS FACTOR IN HEATMAP, WE CAN SAY THAT # BOOKS INFLUENCES 8.2 MARKS IN READING WHICH IS HIGH AND 2.5 MARKS THE LEAST IN MATHS AND THE USE DICTIONARY INFLUENCE ON TOTAL SCORE IS 4.7 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER DISTANCE AS ONE OF THE FACTOR <h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Distance'])['Maths %','Science %','Reading %','Social %','Total'].mean()
x.drop(0,inplace=True)
#Calculating the Difference of max and min value that influence the marks based on factor
Distance=pd.DataFrame(x.max()-x.min(),columns=['Distance'])
fig,axs=plt.subplots(ncols=2,figsize=(16,6))
plt.figure(figsize=(10,10))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Distance,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE DISTANCE AS FACTOR IN HEATMAP, WE CAN SAY THAT DISTANCE INFLUENCES 2.2 MARKS IN MATHS WHICH IS HIGH AND 0.8 MARKS THE LEAST IN TOTAL MARKS AND THE DISTANCE INFLUENCE ON TOTAL SCORE IS 0.8 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER COMPUTER USE AS ONE OF THE FACTOR <h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Computer use'])['Maths %','Science %','Reading %','Social %','Total'].mean()
x.drop(0,inplace=True)
#Calculating the Difference of max and min value that influence the marks based on factor
Computer_use=pd.DataFrame(x.max()-x.min(),columns=['Computer_use'])
fig,axs=plt.subplots(ncols=2,figsize=(18,7))
plt.figure(figsize=(10,10))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Computer_use,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE COMPUTER USE AS FACTOR IN HEATMAP, WE CAN SAY THAT COMPUTER USE INFLUENCES 6.5 MARKS IN MATHS WHICH IS HIGH AND 3.2 MARKS THE LEAST IN SCIENCE AND THE COMPUTER USE INFLUENCE ON TOTAL SCORE IS 3.4 MARKS <h6>

# %% [markdown]
# <h3>CONSIDER LIBRARY USE AS ONE OF THE FACTOR <h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Library use'])['Maths %','Science %','Reading %','Social %','Total'].mean()
x.drop(0,inplace=True)
#Calculating the Difference of max and min value that influence the marks based on factor
Library_use=pd.DataFrame(x.max()-x.min(),columns=['Library_use'])
fig,axs=plt.subplots(ncols=2,figsize=(18,12))
plt.figure(figsize=(10,10))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Library_use,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE LIBRARY USE AS FACTOR IN HEATMAP, WE CAN SAY THAT LIBRARY USE INFLUENCES 5.6 MARKS IN READING WHICH IS HIGH AND 2.7 MARKS THE LEAST IN SCIENCE AND THE LIBRARY USE INFLUENCE ON TOTAL SCORE IS 2.8 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER PRIVATE TUTION AS ONE OF THE FACTOR <h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Private tuition'])['Maths %','Science %','Reading %','Social %','Total'].mean()
x.drop(0,inplace=True)
#Calculating the Difference of max and min value that influence the marks based on factor
Private_tuition=pd.DataFrame(x.max()-x.min(),columns=['Private_tuition'])
fig,axs=plt.subplots(ncols=2,figsize=(16,5))
plt.figure(figsize=(10,10))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Private_tuition,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE PRIVATE TUTION AS FACTOR IN HEATMAP, WE CAN SAY THAT PRIVATE TUTION INFLUENCES 2.1 MARKS IN READING WHICH IS HIGH AND 0.3 MARKS THE LEAST IN SOCIAL AND THE PRIVATE TUTION INFLUENCE ON TOTAL SCORE IS 1.3 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER HELP IN HOUSEHOLD AS ONE OF THE FACTOR <h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Help in household'])['Maths %','Science %','Reading %','Social %','Total'].mean()
x.drop(0,inplace=True)
#Calculating the Difference of max and min value that influence the marks based on factor
Help_in_household=pd.DataFrame(x.max()-x.min(),columns=['Help_in_household'])
fig,axs=plt.subplots(ncols=2,figsize=(16,6))
plt.figure(figsize=(10,10))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Help_in_household,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE HELP IN HOUSEHOLD AS FACTOR IN HEATMAP, WE CAN SAY THAT HELP IN HOUSEHOLD INFLUENCES 6.5 MARKS IN SOCIAL WHICH IS HIGH AND 4.6 MARKS THE LEAST IN MATHS AND THE HELP IN HOUSEHOLD INFLUENCE ON TOTAL SCORE IS 5.2 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER READ MAGAZINE AS ONE OF THE FACTOR <h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Read magazine'])['Maths %','Science %','Reading %','Social %','Total'].mean()
x.drop(0,inplace=True)
#Calculating the Difference of max and min value that influence the marks based on factor
Read_magazine=pd.DataFrame(x.max()-x.min(),columns=['Read_magazine'])
fig,axs=plt.subplots(ncols=2,figsize=(16,6))
plt.figure(figsize=(10,10))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Read_magazine,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE READ MAGAZINE AS FACTOR IN HEATMAP, WE CAN SAY THAT READ MAGAZINE INFLUENCES 7.2 MARKS IN READING WHICH IS HIGH AND 1.6 MARKS THE LEAST IN MATHS AND THE READ MAGAZINE INFLUENCE ON TOTAL SCORE IS 3.4 MARKS<h6>

# %% [markdown]
# <h3>CONSIDER READ A BOOK AS ONE OF THE FACTOR <h3>

# %%
#Using grouop by to aggregate the Dataset on marks with factor
x=df.groupby(['Read a book'])['Maths %','Science %','Reading %','Social %','Total'].mean()
x.drop(0,inplace=True)
#Calculating the Difference of max and min value that influence the marks based on factor
Read_a_book=pd.DataFrame(x.max()-x.min(),columns=['Read_a_book'])
fig,axs=plt.subplots(ncols=2,figsize=(16,7))
sns.heatmap(data=x,ax=axs[1],annot=True,fmt='.1f')
sns.heatmap(data=Read_a_book,annot=True,fmt='.1f',ax=axs[0])

# %% [markdown]
# <h6>HERE WE CAN SEE READ A BOOK AS FACTOR IN HEATMAP, WE CAN SAY THAT READ A BOOK INFLUENCES 7.1 MARKS IN READING WHICH IS HIGH AND 2.0 MARKS THE LEAST IN MATHS AND THE READ A BOOK INFLUENCE ON TOTAL SCORE IS 3.7 MARKS<h6>

# %% [markdown]
# <h3>COMBINE ALL THE FACTORS<h3>

# %%
combine_factors=pd.concat([Gender,Age,Siblings,Father_edu,Mother_edu,Father_occupation,Mother_occupation,Below_poverty,Use_calculator,Use_dictionary,Read_other_books,Have_Books,Distance,Computer_use,Library_use,Private_tuition,Help_in_household,Read_magazine,Read_a_book],axis=1)

# %%
fig, ax = plt.subplots(figsize=(20,4)) 
sns.heatmap(data=combine_factors,annot=True,fmt='.2f',ax=ax)

# %% [markdown]
# <h2>CONCLUSION<h2>

# %% [markdown]
# <h3>FROM THE ABOVE HEATMAP WE CAN SEE THE FACTORS THAT INFLUENCE STUDENT TO SCORE MORE ARE  1.FATHER EDUCATION   11 MARKS <br> 2.MOTHER EDUCATION  10.72 MARKS <br>3.FATHER OCCUPATION  10.60 MARKS <br>  4.MOTHER OCCUPATION   9.13 MARKS <h3>

# %% [markdown]
# <h1>2.HOW BOYS AND GIRLS PERFORM ACCROSS THE STATES ?<h1>

# %% [markdown]
# <h3>BOYS PERFORMANCE ACCROSS STATES<h3>

# %%
Boy=df[df['Gender']=='Boy']
Boy_performance=Boy.groupby(['state'])['Total'].mean()
performance.plot(kind='bar',figsize=(20,7))

# %% [markdown]
# <h5>WE CAN SEE FROM THE GRAPH THAT BOYS PERFORMED BEST IN  DAMMAN & DIU,UTTAR PRADESH AND WORST IN PONDICHERRY,TAMILNADU AND MEGHALAYA<h5>

# %% [markdown]
# <h3>GIRLS PERFORMANCE ACCROSS STATES<h3>

# %%
Girl=df[df['Gender']=='Girl']
Girl_performance=Girl.groupby(['state'])['Total'].mean()
performance.plot(kind='bar',figsize=(20,7))

# %% [markdown]
# <h5><h5>WE CAN SEE FROM THE GRAPH THAT GIRLS PERFORMED BEST IN  DAMMAN & DIU,UTTAR PRADESH,KERALA,DADRA AND NAGAR HAVELI  AND WORST IN PONDICHERRY,TAMILNADU AND MEGHALAYA<h5>

# %% [markdown]
# <h3>NOW FIND THE DIFFERENCE TO KNOW WHO SCORE THE BEST AMONG STATES<h3>

# %%
difference=Girl_performance-Boy_performance

# %%
difference.plot(kind='bar',figsize=(20,7))

# %% [markdown]
# <h5>BY THIS WE CAN SAY THAT GIRL PERFORMS BEST MARKS IN THE STATES OF KERALA,GOA  AND LESS MARKS IN STATES OF JHARKHAND,BIHAR<br> AND BOYS IS VICE VERSA FOR GIRLS BECAUSE WE ARE SUBTRACTING GIRLS MARKS FROM BOYS MARKS<h5>

# %% [markdown]
# <h1>3.DOES STUDENTS FROM SOUTH INDIAN STATES REALLY EXCEL AT MATHS AND SCIENCE ?<h1>

# %%
#Create dictionary to map Zones Based on Particular State
zones={'AN':'SOUTH','AP':'SOUTH','AR':'NORTH EAST','BR':'EAST','CG':'CENTRAL','CH':'NORTH','DD':'WEST','DL':'NORTH','DN':'WEST','GA':'WEST','GJ':'WEST','HP':'NORTH','HR':'NORTH','JH':'EAST','JK':'NORTH','KA':'SOUTH','KL':'SOUTH','MG':'NORTH EAST','MH':'WEST','MN':'NORTH EAST','MP':'CENTRAL','MZ':'NORTH EAST','NG':'NORTH EAST','OR':'EAST','PB':'NORTH','PY':'SOUTH','RJ':'NORTH','SK':'NORTH EAST','TN':'SOUTH','TR':'NORTH EAST','UK':'NORTH','UP':'NORTH','WB':'EAST'}

# %%
#creating a new column Zone in the Data Frame
df['ZONE'] = df['State'].map(zones)

# %%
south_performance=df.groupby(['ZONE'])['Maths %','Science %'].mean()
south_performance.plot(kind='bar',figsize=(20,7))

# %% [markdown]
# <h2>FINALLY STUDENTS FROM SOUTH INDIAN STATES ARE NOT PERFORMING WELL IN BOTH MATHS AND SCIENCE<h2>
